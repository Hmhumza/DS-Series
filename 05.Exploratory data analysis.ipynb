# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
kashti = sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#save data set  in my pc
kashti.to_csv("kashti.csv")

# %%
#to chech what type of data is
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
#to findout how many rows and col
#(rows,col)
kashti.shape
# Out:
# (891, 15)

# %%
#get info of numeric data
kashti.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#get unique values of  data
kashti.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
#get column names
kashti.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
kashti["sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
#findout unique values of 2 & more than 2 col 
kashti[['sex', 'age', 'who', 'adult_male']].nunique() #not working for unique value it give no's
# Out:
# sex            2
# age           88
# who            3
# adult_male     2
# dtype: int64

# %%
#or
kdata = kashti.columns                                     # defining a new string to pull out the index names
for k in kdata:                                           # starting for -loop
    print(kashti[k].unique())                            # print out the values for individual unique column
print()
# Out:
# [0 1]
# [3 1 2]
# ['male' 'female']
# [22.   38.   26.   35.     nan 54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 30.   33.   23.   24.   46.   59.   71.   37.   47.
#  14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.
#  56.   50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.
#  60.   10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.
#   0.67 30.5   0.42 34.5  74.  ]
# [1 0 3 4 2 5 8]
# [0 1 2 5 3 4 6]
# [  7.25    71.2833   7.925   53.1      8.05     8.4583  51.8625  21.075
#   11.1333  30.0708  16.7     26.55    31.275    7.8542  16.      29.125
#   13.      18.       7.225   26.       8.0292  35.5     31.3875 263.
#    7.8792   7.8958  27.7208 146.5208   7.75    10.5     82.1708  52.
#    7.2292  11.2417   9.475   21.      41.5792  15.5     21.6792  17.8
# ...

# %%
print(kashti[['who','adult_male']].nunique())
print(pd.unique(kashti[['who','adult_male']].values.ravel('K')))
# Out:
# who           3
# adult_male    2
# dtype: int64
# ['man' 'woman' 'child' True False]

# %% [markdown]
# ## Cleaning and Filtering the Data

# %%
#findout misssing values
#jahn true aayega matlab wo null value h
kashti.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
#sum of null values
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#jahan missing values zyada ho unhy drop krdo us col ko
#removing missingg value col(data cleaning)
kashti_clean = kashti.drop(["deck"], axis=1)
kashti_clean
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
kashti_clean.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
age=177
row=891
data=row-age
data
# so we dont drop age data
# Out:
# 714

# %%
kashti_clean = kashti_clean.dropna()

# %%
kashti_clean
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
kashti_clean["sex"].value_counts()
# Out:
# male      453
# female    259
# Name: sex, dtype: int64

# %%
kashti.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
kashti_clean.describe()
# here why we do cleaning bcz null value impact on our data
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    2.240169   29.642093    0.514045    0.432584   34.567251
# std      0.491139    0.836854   14.492933    0.930692    0.854181   52.938648
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000    0.000000   15.645850
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   33.000000
# max      1.000000    3.000000   80.000000    5.000000    6.000000  512.329200

# %%
sns.boxplot(x='sex',y='age', data=kashti_clean)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
#yhn humy paat laga k age me masla hai data bahar jarha hai sqk jo max value sy bahar jati wo outliers hoty hamy remove krna 
# hota hai
sns.boxplot(y='age', data=kashti_clean)
# Out:
# <AxesSubplot:ylabel='age'>

# %%
sns.distplot(kashti_clean["age"])
#isko hum normality check,belcurve or histogram or ditance plot  bhi khty
#yhn shape teri horhi hai
#yhn data ki dispersion khn zyada hai dekh k usy normal krty means perfectly bell curve bnaty
#dispersion or mean dekhi jati jo outlier py impact krti
# Out:
# C:\Users\Muhammad Maaz\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
#remove Outliers
print(kashti_clean["age"].mean())
# Out:
# 29.64209269662921

# %%
kashti_clean.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
ks_clean = kashti_clean[kashti_clean["age"] < 68]
ks_clean.head()
#but it gives boolean values we want it numeric
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
#now we check how many rows are left after removing outliers
ks_clean.shape
# Out:
# (705, 14)

# %%
sns.boxplot(y='age', data=ks_clean)
# Out:
# <AxesSubplot:ylabel='age'>

# %%
sns.distplot(ks_clean["age"])
#yhn outliers tw remove hogye bas ek point rehgya lkn belcurve masla kr raha jisy remove krdngy abhi filhal baad me isy kesy sahi krna dekhngy
# Out:
# C:\Users\Muhammad Maaz\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
ks_clean.boxplot()
#yhn fare me bhtsy outliers hain jisme ek point bht masla kr rah usy bhi remove krngy
# Out:
# <AxesSubplot:>

# %%
ks_clean = kashti_clean[kashti_clean["fare"] <300]
ks_clean.boxplot()
#ab or bikhar gya data lkn hum remove nhi krngy
#qk ye outliers nhi h
#hum agr isy remove krty rahyngy tw data bht kam bach jayega islye remv nhi krngy
# Out:
# <AxesSubplot:>

# %%
sns.distplot(ks_clean["fare"])
#yhn right py dispersion h mean data normal nhi h
#normal krny klye bht sy kaam krny party like log transformation
# Out:
# C:\Users\Muhammad Maaz\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
ks_clean.hist()
# Out:
# array([[<AxesSubplot:title={'center':'survived'}>,
#         <AxesSubplot:title={'center':'pclass'}>],
#        [<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sibsp'}>],
#        [<AxesSubplot:title={'center':'parch'}>,
#         <AxesSubplot:title={'center':'fare'}>]], dtype=object)

# %%
pd.value_counts(ks_clean["sex"]).plot.bar()
# Out:
# <AxesSubplot:>

# %%
#after clean data
ks_clean.groupby(["sex","class"]).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.963415     1.0  34.231707  0.560976  0.512195  103.696393
#        Second  0.918919     2.0  28.722973  0.500000  0.621622   21.951070
#        Third   0.460784     3.0  21.750000  0.823529  0.950980   15.875369
# male   First   0.383838     1.0  41.398182  0.383838  0.333333   62.229924
#        Second  0.151515     2.0  30.740707  0.373737  0.242424   21.113131
#        Third   0.150198     3.0  26.507589  0.490119  0.256917   12.162695
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.353659
#        Second    0.000000  0.405405
#        Third     0.000000  0.372549
# male   First     0.969697  0.535354
#        Second    0.909091  0.636364
#        Third     0.889328  0.739130

# %%
#before clean data
kashti.groupby(["sex","class"]).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.968085     1.0  34.611765  0.553191  0.457447  106.125798
#        Second  0.921053     2.0  28.722973  0.486842  0.605263   21.970121
#        Third   0.500000     3.0  21.750000  0.895833  0.798611   16.118810
# male   First   0.368852     1.0  41.281386  0.311475  0.278689   67.226127
#        Second  0.157407     2.0  30.740707  0.342593  0.222222   19.741782
#        Third   0.135447     3.0  26.507589  0.498559  0.224784   12.661633
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.361702
#        Second    0.000000  0.421053
#        Third     0.000000  0.416667
# male   First     0.975410  0.614754
#        Second    0.916667  0.666667
#        Third     0.919308  0.760807

# %%
#Now we move on Relationship
corr_ks_clean = ks_clean.corr()
corr_ks_clean
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.351579 -0.084756 -0.012733  0.096227  0.272376
# pclass     -0.351579  1.000000 -0.365259  0.062048  0.023059 -0.616062
# age        -0.084756 -0.365259  1.000000 -0.306731 -0.187967  0.096573
# sibsp      -0.012733  0.062048 -0.306731  1.000000  0.383571  0.199056
# parch       0.096227  0.023059 -0.187967  0.383571  1.000000  0.260993
# fare        0.272376 -0.616062  0.096573  0.199056  0.260993  1.000000
# adult_male -0.554883  0.096376  0.286850 -0.313431 -0.367582 -0.228012
# alone      -0.201829  0.152884  0.196009 -0.630592 -0.576332 -0.335132
#
#             adult_male     alone
# survived     -0.554883 -0.201829
# pclass        0.096376  0.152884
# age           0.286850  0.196009
# sibsp        -0.313431 -0.630592
# parch        -0.367582 -0.576332
# fare         -0.228012 -0.335132
# adult_male    1.000000  0.404087
# alone         0.404087  1.000000

# %%
sns.heatmap(corr_ks_clean)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(corr_ks_clean,annot=True)
# Out:
# <AxesSubplot:>

# %%
#srf numerical values ka co relation hota hai
sns.relplot(x="age",y="fare",data=ks_clean,hue="sex")

# %%
#log transformation
sns.distplot(ks_clean["fare"])
ks_clean["fare_log"] = np.log(ks_clean["fare"])
ks_clean["fare_log"]
# Out:
# C:\Users\Muhammad Maaz\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Muhammad Maaz\anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\MUHAMM~1\AppData\Local\Temp/ipykernel_7120/1175775556.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks_clean["fare_log"] = np.log(ks_clean["fare"])
# 0      1.981001
# ...

# %%
ks_clean.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone  fare_log
# 0    man        True  Southampton    no  False  1.981001
# 1  woman       False    Cherbourg   yes  False  4.266662
# 2  woman       False  Southampton   yes   True  2.070022
# 3  woman       False  Southampton   yes  False  3.972177
# 4    man        True  Southampton    no   True  2.085672

# %%
#Assignment 
#make a box plot of fare log and find the diff b/w fare and fare log
sns.catplot(x="sex",y="fare",data=ks_clean,kind="box",hue="sex")

# %%
sns.catplot(x="sex",y="fare_log",data=ks_clean,kind="box",hue="sex")
